# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("text-generation", model="PleIAs/Pleias-RAG-1B")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 4
#       1 # Use a pipeline as a high-level helper
#       2 from transformers import pipeline
# ----> 4 pipe = pipeline("text-generation", model="PleIAs/Pleias-RAG-1B")
#
# File ~/miniconda3/envs/llm-dev-old/lib/python3.10/site-packages/transformers/pipelines/__init__.py:906, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, framework, revision, use_fast, token, device, device_map, torch_dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     904 if isinstance(model, str) or framework is None:
#     905     model_classes = {"tf": targeted_task["tf"], "pt": targeted_task["pt"]}
# --> 906     framework, model = infer_framework_load_model(
#     907         model,
#     908         model_classes=model_classes,
#     909         config=config,
# ...
